# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

from src.loaders import initialise_gos_l_sheet, initialise_gos_sheet
from src.parsers.qilt import parse_qilt_sheet
from src.preparation.qilt import prepare_qilt_sheet

# %%
gos_8_sheet = initialise_gos_sheet(8)  # GOS 8

gos_8_table = parse_qilt_sheet(gos_8_sheet.folder, gos_8_sheet.file_name, gos_8_sheet.sheet_name).table
gos_8_table

# %%
gos_8_prepared_sheet = prepare_qilt_sheet(gos_8_sheet.folder, gos_8_sheet.file_name, gos_8_sheet.sheet_name)
gos_8_table = gos_8_prepared_sheet.table
gos_8_table

# %%
gos_l_160_sheet = initialise_gos_l_sheet(160)  # GOS-L 160
gos_l_160_prepared_sheet = prepare_qilt_sheet(gos_l_160_sheet.folder, gos_l_160_sheet.file_name, gos_l_160_sheet.sheet_name)
gos_l_160_table = gos_l_160_prepared_sheet.table
gos_l_160_table

# %%
from src.transform.chart_4_gap_shapes import build_chart_4_table

chart_4_gap_shapes_table = build_chart_4_table(
    gos_8_prepared_sheet,
    gos_l_160_prepared_sheet,
)
chart_4_gap_shapes_table
